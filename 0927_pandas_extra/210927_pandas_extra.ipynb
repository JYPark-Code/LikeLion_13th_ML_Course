# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
os.listdir()

import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
import matplotlib
import platform

path = "C:/Windows/Fonts/malgun.ttf"
if platform.system() == "Windows":
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
elif platform.system()=="Darwin":
    rc('font', family='AppleGothic')
else:
    print("Unknown System")
    
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
corona = pd.read_csv("20210921_00_datamerge.csv")
corona.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 21 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   국가명         178 non-null    object
#  1   eng_code    178 non-null    object
#  2   발생률         178 non-null    int64
#  3   인구수         178 non-null    int64
#  4   확진자_합계      178 non-null    int64
#  5   백신접종        178 non-null    float64
#  6   접종률(인구)     178 non-null    float64
#  7   발생률_순위      178 non-null    float64
#  8   접종률_순위      178 non-null    float64
#  9   확진자비율_전체인구  178 non-null    float64
#  10  1차접종        178 non-null    float64
#  11  2차접종        178 non-null    float64
#  12  위중증         131 non-null    object
#  13  치명(%)       178 non-null    object
#  14  완치(%)       175 non-null    float64
#  15  확진자1일       130 non-null    float64
#  16  사망자합계       178 non-null    int64
#  17  사망자1일       104 non-null    float64
#  18  완치합계        175 non-null    float64
# ...

# %%
corona.shape
# Out:
# (178, 21)

# %%
pd.options.display.max_columns
# Out:
# 20

# %%
pd.options.display.max_rows
# Out:
# 60

# %%
pd.options.display.max_columns = 500
pd.options.display.max_rows = 500

# %%
corona
# Out:
#          국가명               eng_code     발생률         인구수    확진자_합계  \
# 0         미국                   U.S.  129632   331002651  42908619
# 1         인도                  India   24277  1380004385  33483170
# 2        브라질                 Brazil   99924   212559417  21239783
# 3         영국                   U.K.  109444    67886011   7429746
# 4        러시아                 Russia   49986   145934462   7294672
# 5        프랑스                 France  106557    65273511   6955333
# 6         터키                 Turkey   81187    84339067   6847259
# 7         이란                   Iran   64794    83992949   5442232
# 8      아르헨티나              Argentina  115923    45195774   5239232
# 9       콜롬비아               Colombia   97107    50882891   4941064
# 10       스페인                  Spain  105434    46754778   4929546
# 11      이탈리아                  Italy   76678    60461826   4636111
# 12     인도네시아              Indonesia   15328   273523615   4192695
# ...

# %%
corona.columns
# Out:
# Index(['국가명', 'eng_code', '발생률', '인구수', '확진자_합계', '백신접종', '접종률(인구)', '발생률_순위',
#        '접종률_순위', '확진자비율_전체인구', '1차접종', '2차접종', '위중증', '치명(%)', '완치(%)',
#        '확진자1일', '사망자합계', '사망자1일', '완치합계', '완치1일', '접종비율(일간)'],
#       dtype='object')

# %% [markdown]
# ### 컬럼명 변경

# %%
corona.columns = ['국가명', 'eng_code', '발생률', '인구수', '확진자_합계', '백신접종', '백신보유량(인구)', '발생률_순위',
       '접종률_순위', '확진자비율_전체인구', '1차접종', '2차접종', '위중증', '치명(%)', '완치(%)',
       '확진자1일', '사망자합계', '사망자1일', '완치합계', '완치1일', '접종비율(일간)']

# %%
corona = corona.drop(['확진자비율_전체인구'], axis=1)
corona.columns
# Out:
# Index(['국가명', 'eng_code', '발생률', '인구수', '확진자_합계', '백신접종', '백신보유량(인구)',
#        '발생률_순위', '접종률_순위', '1차접종', '2차접종', '위중증', '치명(%)', '완치(%)', '확진자1일',
#        '사망자합계', '사망자1일', '완치합계', '완치1일', '접종비율(일간)'],
#       dtype='object')

# %%
corona["인구당확진자비율"] = corona["확진자_합계"] / corona["인구수"]
corona.head()
# Out:
#    국가명 eng_code     발생률         인구수    확진자_합계         백신접종  백신보유량(인구)  발생률_순위  \
# 0   미국     U.S.  129632   331002651  42908619  385586020.0       60.2    13.0
# 1   인도    India   24277  1380004385  33483170  808389300.0       29.6   101.0
# 2  브라질   Brazil   99924   212559417  21239783  222322660.0       53.9    27.0
# 3   영국     U.K.  109444    67886011   7429746   93002090.0       69.6    21.0
# 4  러시아   Russia   49986   145934462   7294672   87810616.0       29.9    77.0
#
#    접종률_순위  1차접종  2차접종          위중증 치명(%)  완치(%)    확진자1일   사망자합계  사망자1일  \
# 0    46.0  63.8  54.6  24327\n-523   1.6   75.8  41814.0  691992  430.0
# 1    99.0  43.7  14.5         8944   1.3   97.7  32085.0  445248  349.0
# 2    62.0  69.4  37.8         8318   2.8   95.5   9458.0  590786  239.0
# 3    25.0  72.7  66.5         1020   1.8   80.5  29007.0  135203   56.0
# 4    97.0  31.9  27.6         2300   2.7   89.3  19744.0  198996  778.0
#
#          완치합계     완치1일   접종비율(일간)  인구당확진자비율
# ...

# %% [markdown]
# ### 인구당확진자비율과 백신 접종률에 대한 상관관계

# %%
sns.scatterplot(x="발생률", y="2차접종", data=corona)
# Out:
# <AxesSubplot:xlabel='발생률', ylabel='2차접종'>

# %%
corona.loc[corona["2차접종"]<0 , :]
# Out:
#         국가명    eng_code   발생률      인구수  확진자_합계      백신접종  백신보유량(인구)  발생률_순위  \
# 143     레소토     Lesotho  6720  2142249   14395  201795.0        4.9   126.0
# 177  미크로네시아  Micronesia     9   115023       1   69970.0       33.6   178.0
#
#      접종률_순위  1차접종   2차접종  위중증 치명(%)  완치(%)  확진자1일  사망자합계  사망자1일    완치합계  완치1일  \
# 143   147.0   2.0 -999.0  NaN   2.8   47.4    NaN    403    NaN  6830.0   NaN
# 177    89.0  40.8 -999.0  NaN     -  100.0    NaN      0    NaN     1.0   NaN
#
#      접종비율(일간)  인구당확진자비율
# 143   24504.0  0.006720
# 177     242.0  0.000009

# %%
corona = corona.loc[corona["2차접종"] > 0 , :]

# %%
corona.loc[corona["2차접종"]<0 , :]
# Out:
# Empty DataFrame
# Columns: [국가명, eng_code, 발생률, 인구수, 확진자_합계, 백신접종, 백신보유량(인구), 발생률_순위, 접종률_순위, 1차접종, 2차접종, 위중증, 치명(%), 완치(%), 확진자1일, 사망자합계, 사망자1일, 완치합계, 완치1일, 접종비율(일간), 인구당확진자비율]
# Index: []

# %%
sns.scatterplot(x="발생률", y="2차접종", data=corona)
# Out:
# <AxesSubplot:xlabel='발생률', ylabel='2차접종'>

# %%
corona [["발생률", "2차접종"]].corr()
# Out:
#            발생률      2차접종
# 발생률   1.000000  0.578879
# 2차접종  0.578879  1.000000

# %%
sns.lmplot(x="발생률", y="2차접종", data=corona)

# %% [markdown]
# ### 실습: 인구당 확진자 비율과 2차 접종률의 상관관계를 찍어보자

# %%
corona["사망률"] = corona["사망자합계"] / corona["인구수"]

# %%
corona.head()
# Out:
#    국가명 eng_code     발생률         인구수    확진자_합계         백신접종  백신보유량(인구)  발생률_순위  \
# 0   미국     U.S.  129632   331002651  42908619  385586020.0       60.2    13.0
# 1   인도    India   24277  1380004385  33483170  808389300.0       29.6   101.0
# 2  브라질   Brazil   99924   212559417  21239783  222322660.0       53.9    27.0
# 3   영국     U.K.  109444    67886011   7429746   93002090.0       69.6    21.0
# 4  러시아   Russia   49986   145934462   7294672   87810616.0       29.9    77.0
#
#    접종률_순위  1차접종  2차접종          위중증 치명(%)  완치(%)    확진자1일   사망자합계  사망자1일  \
# 0    46.0  63.8  54.6  24327\n-523   1.6   75.8  41814.0  691992  430.0
# 1    99.0  43.7  14.5         8944   1.3   97.7  32085.0  445248  349.0
# 2    62.0  69.4  37.8         8318   2.8   95.5   9458.0  590786  239.0
# 3    25.0  72.7  66.5         1020   1.8   80.5  29007.0  135203   56.0
# 4    97.0  31.9  27.6         2300   2.7   89.3  19744.0  198996  778.0
#
#          완치합계     완치1일   접종비율(일간)  인구당확진자비율       사망률
# ...

# %%
corona[["사망률", "2차접종"]].corr()
# Out:
#            사망률      2차접종
# 사망률   1.000000  0.343234
# 2차접종  0.343234  1.000000

# %%
sns.lmplot(x="2차접종", y="사망률", data=corona)

# %% [markdown]
# ### 백신 접종률과 중증 감소의 관계

# %%
corona["위중증"].unique()
# Out:
# array(['24327\n-523', '8944', '8318', '1020', '2300', '1832\n-168', '633',
#        '6707\n-58', '1496\n-20', '542', '1028', '530\n+11', nan, '1217',
#        '4798', '113\n+2', '3170', '177', '1043\n+9', '1191\n+26',
#        '208\n+11', '618\n+2', '28\n-1', '1458\n-42', '434\n-4', '638',
#        '1403', '4387', '714\n-12', '4840\n-124', '218', '952\n+103', '43',
#        '86\n-4', '776\n+3', '181\n-2', '221', '260\n+3', '45\n+4',
#        '509\n+2', '503\n+42', '219\n+7', '380\n-5', '348', '200',
#        '339\n-4', '5', '759', '489', '220', '391\n-5', '108', '37\n+1',
#        '16\n-1', '60\n+1', '85\n+4', '11', '63\n-3', '515', '681',
#        '22\n-1', '784\n-16', '166\n+4', '19\n-8', '90', '332\n-1',
#        '63\n+3', '100\n+6', '192', '2', '109', '19\n+1', '21\n-3',
#        '20\n+1', '131', '1', '23', '3', '1124', '36\n-2', '18', '32',
#        '20', '12', '19', '42', '381', '45', '127\n-31', '19\n-4', '292',
# ...

# %%
corona["위중증"].str.split("\n", expand=True)
# Out:
#          0     1
# 0    24327  -523
# 1     8944  None
# 2     8318  None
# 3     1020  None
# 4     2300  None
# 5     1832  -168
# 6      633  None
# 7     6707   -58
# 8     1496   -20
# 9      542  None
# 10    1028  None
# 11     530   +11
# 12     NaN   NaN
# 13    1217  None
# 14    4798  None
# 15     113    +2
# 16    3170  None
# 17     177  None
# 18    1043    +9
# 19    1191   +26
# 20     208   +11
# 21     618    +2
# 22      28    -1
# 23    1458   -42
# 24     434    -4
# 25     638  None
# 26    1403  None
# 27    4387  None
# 28     714   -12
# 29    4840  -124
# 30     218  None
# 31     952  +103
# 32      43  None
# 33      86    -4
# 34     776    +3
# 35     181    -2
# 36     221  None
# 37     260    +3
# 38      45    +4
# 39     509    +2
# 40     503   +42
# 41     NaN   NaN
# 42     NaN   NaN
# 43     219    +7
# 44     380    -5
# 45     NaN   NaN
# 46     348  None
# 47     200  None
# 48     NaN   NaN
# 49     339    -4
# 50       5  None
# ...

# %%
corona[["위중증_수", "위중증_증감"]] = corona["위중증"].str.split("\n", expand=True)
corona.head()
# Out:
#    국가명 eng_code     발생률         인구수    확진자_합계         백신접종  백신보유량(인구)  발생률_순위  \
# 0   미국     U.S.  129632   331002651  42908619  385586020.0       60.2    13.0
# 1   인도    India   24277  1380004385  33483170  808389300.0       29.6   101.0
# 2  브라질   Brazil   99924   212559417  21239783  222322660.0       53.9    27.0
# 3   영국     U.K.  109444    67886011   7429746   93002090.0       69.6    21.0
# 4  러시아   Russia   49986   145934462   7294672   87810616.0       29.9    77.0
#
#    접종률_순위  1차접종  2차접종          위중증 치명(%)  완치(%)    확진자1일   사망자합계  사망자1일  \
# 0    46.0  63.8  54.6  24327\n-523   1.6   75.8  41814.0  691992  430.0
# 1    99.0  43.7  14.5         8944   1.3   97.7  32085.0  445248  349.0
# 2    62.0  69.4  37.8         8318   2.8   95.5   9458.0  590786  239.0
# 3    25.0  72.7  66.5         1020   1.8   80.5  29007.0  135203   56.0
# 4    97.0  31.9  27.6         2300   2.7   89.3  19744.0  198996  778.0
#
# ...

# %%
# 위중증률 = 위중증 / 인구수
corona["위중증률"] = corona["위중증_수"] / corona["인구수"]
corona.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in _na_arithmetic_op(left, right, op, is_cmp)
#     141     try:
# --> 142         result = expressions.evaluate(op, left, right)
#     143     except TypeError:
#
# ~\anaconda3\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, a, b, use_numexpr)
#     234             # error: "None" not callable
# --> 235             return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     236     return _evaluate_standard(op, op_str, a, b)
#
# ~\anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_numexpr(op, op_str, a, b)
#     119     if result is None:
# --> 120         result = _evaluate_standard(op, op_str, a, b)
#     121
#
# ...

# %%
corona.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 176 entries, 0 to 176
# Data columns (total 24 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   국가명        176 non-null    object
#  1   eng_code   176 non-null    object
#  2   발생률        176 non-null    int64
#  3   인구수        176 non-null    int64
#  4   확진자_합계     176 non-null    int64
#  5   백신접종       176 non-null    float64
#  6   백신보유량(인구)  176 non-null    float64
#  7   발생률_순위     176 non-null    float64
#  8   접종률_순위     176 non-null    float64
#  9   1차접종       176 non-null    float64
#  10  2차접종       176 non-null    float64
#  11  위중증        131 non-null    object
#  12  치명(%)      176 non-null    object
#  13  완치(%)      173 non-null    float64
#  14  확진자1일      130 non-null    float64
#  15  사망자합계      176 non-null    int64
#  16  사망자1일      104 non-null    float64
#  17  완치합계       173 non-null    float64
#  18  완치1일       115 non-null    float64
# ...

# %%
corona.isnull().sum()
# Out:
# 국가명            0
# eng_code       0
# 발생률            0
# 인구수            0
# 확진자_합계         0
# 백신접종           0
# 백신보유량(인구)      0
# 발생률_순위         0
# 접종률_순위         0
# 1차접종           0
# 2차접종           0
# 위중증           45
# 치명(%)          0
# 완치(%)          3
# 확진자1일         46
# 사망자합계          0
# 사망자1일         72
# 완치합계           3
# 완치1일          61
# 접종비율(일간)       0
# 인구당확진자비율       0
# 사망률            0
# 위중증_수         45
# 위중증_증감       126
# dtype: int64

# %%
corona.loc[corona["위중증_수"].isnull() , :]
# Out:
#          국가명               eng_code     발생률         인구수   확진자_합계  \
# 12     인도네시아              Indonesia   15328   273523615  4192695
# 41        네팔                  Nepal   26960    29136808   785541
# 42   아랍에미레이트                    UAE   74113     9890402   733003
# 45       베트남                Vietnam    7148    97338579   695744
# 48       조지아                Georgia  149386     3989167   595926
# 51      벨라루스                Belarus   54858     9449323   518369
# 54      스리랑카              Sri Lanka   23560    21413249   504491
# 57    아제르바이잔             Azerbaijan   46623    10139177   472719
# 60       미얀마                Myanmar    8208    54409800   446573
# 70       리비아                  Libya   48321     6871292   332026
# 79     아르메니아                Armenia   85697     2963243   253942
# 85    북마케도니아        North Macedonia   89717     2083374   186914
# 102      코소보                 Kosovo   59381     1810463   107507
# ...

# %%
corona["위중증_수2"] = corona["위중증_수"].copy()

# %%
corona.loc[ corona["위중증_수2"].isnull(), "위중증_수2"] = -99999

#확인
corona.loc[ corona["위중증_수2"].isnull(), : ]
# Out:
# Empty DataFrame
# Columns: [국가명, eng_code, 발생률, 인구수, 확진자_합계, 백신접종, 백신보유량(인구), 발생률_순위, 접종률_순위, 1차접종, 2차접종, 위중증, 치명(%), 완치(%), 확진자1일, 사망자합계, 사망자1일, 완치합계, 완치1일, 접종비율(일간), 인구당확진자비율, 사망률, 위중증_수, 위중증_증감, 위중증_수2]
# Index: []

# %%
corona["위중증_수2"] = corona["위중증_수2"].astype("int16")
corona["위중증률"] = corona["위중증_수2"] / corona["인구수"]
corona.head()
# Out:
#    국가명 eng_code     발생률         인구수    확진자_합계         백신접종  백신보유량(인구)  발생률_순위  \
# 0   미국     U.S.  129632   331002651  42908619  385586020.0       60.2    13.0
# 1   인도    India   24277  1380004385  33483170  808389300.0       29.6   101.0
# 2  브라질   Brazil   99924   212559417  21239783  222322660.0       53.9    27.0
# 3   영국     U.K.  109444    67886011   7429746   93002090.0       69.6    21.0
# 4  러시아   Russia   49986   145934462   7294672   87810616.0       29.9    77.0
#
#    접종률_순위  1차접종  2차접종          위중증 치명(%)  완치(%)    확진자1일   사망자합계  사망자1일  \
# 0    46.0  63.8  54.6  24327\n-523   1.6   75.8  41814.0  691992  430.0
# 1    99.0  43.7  14.5         8944   1.3   97.7  32085.0  445248  349.0
# 2    62.0  69.4  37.8         8318   2.8   95.5   9458.0  590786  239.0
# 3    25.0  72.7  66.5         1020   1.8   80.5  29007.0  135203   56.0
# 4    97.0  31.9  27.6         2300   2.7   89.3  19744.0  198996  778.0
#
# ...

# %%
corona_sel = ['국가명', '발생률', '인구수', '확진자_합계', '백신접종', '인구당확진자비율',  
              '2차접종', '사망률', '위중증', '위중증_증감', '위중증_수', '위중증_수2', '위중증률']
corona_part = corona[corona_sel]
corona_part
# Out:
#          국가명     발생률         인구수    확진자_합계          백신접종  인구당확진자비율    2차접종  \
# 0         미국  129632   331002651  42908619  3.855860e+08  0.129632   54.60
# 1         인도   24277  1380004385  33483170  8.083893e+08  0.024263   14.50
# 2        브라질   99924   212559417  21239783  2.223227e+08  0.099924   37.80
# 3         영국  109444    67886011   7429746  9.300209e+07  0.109444   66.50
# 4        러시아   49986   145934462   7294672  8.781062e+07  0.049986   27.60
# 5        프랑스  106557    65273511   6955333  9.226241e+07  0.106557   72.70
# 6         터키   81187    84339067   6847259  1.051146e+08  0.081187   50.50
# 7         이란   64794    83992949   5442232  4.200386e+07  0.064794   16.60
# 8      아르헨티나  115923    45195774   5239232  4.901757e+07  0.115923   44.30
# 9       콜롬비아   97107    50882891   4941064  3.833164e+07  0.097107   31.70
# 10       스페인  105434    46754778   4929546  6.909466e+07  0.105434   77.00
# ...

# %%
sns.lmplot(x='위중증률', y='2차접종', data=corona_part)

# %%
corona_part[['위중증률', '2차접종']].corr()
# Out:
#           위중증률      2차접종
# 위중증률  1.000000  0.058065
# 2차접종  0.058065  1.000000

# %%
corona_part = corona_part [corona_part["위중증"].notnull()]
corona_part["위중증"].isnull().sum()
# Out:
# 0

# %%
print(corona_part[['위중증률', '2차접종']].corr())
sns.lmplot(x="위중증률", y="2차접종", data=corona_part)
# Out:
#           위중증률      2차접종
# 위중증률  1.000000  0.252715
# 2차접종  0.252715  1.000000

# %% [markdown]
# #### 200만명 이상의 나라를 가져와서 데이터 상관관계를 구해보자

# %%
corona_part.columns
# Out:
# Index(['국가명', '발생률', '인구수', '확진자_합계', '백신접종', '인구당확진자비율', '2차접종', '사망률', '위중증',
#        '위중증_증감', '위중증_수', '위중증_수2', '위중증률'],
#       dtype='object')

# %%
corona_pop_5M = corona.loc[corona["인구수"] > 5000000 , :]

# %%
corona_pop_5M
# Out:
#          국가명               eng_code     발생률         인구수    확진자_합계  \
# 0         미국                   U.S.  129632   331002651  42908619
# 1         인도                  India   24277  1380004385  33483170
# 2        브라질                 Brazil   99924   212559417  21239783
# 3         영국                   U.K.  109444    67886011   7429746
# 4        러시아                 Russia   49986   145934462   7294672
# 5        프랑스                 France  106557    65273511   6955333
# 6         터키                 Turkey   81187    84339067   6847259
# 7         이란                   Iran   64794    83992949   5442232
# 8      아르헨티나              Argentina  115923    45195774   5239232
# 9       콜롬비아               Colombia   97107    50882891   4941064
# 10       스페인                  Spain  105434    46754778   4929546
# 11      이탈리아                  Italy   76678    60461826   4636111
# 12     인도네시아              Indonesia   15328   273523615   4192695
# ...

# %%
corona_pop_3M.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 135 entries, 0 to 167
# Data columns (total 26 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   국가명        135 non-null    object
#  1   eng_code   135 non-null    object
#  2   발생률        135 non-null    int64
#  3   인구수        135 non-null    int64
#  4   확진자_합계     135 non-null    int64
#  5   백신접종       135 non-null    float64
#  6   백신보유량(인구)  135 non-null    float64
#  7   발생률_순위     135 non-null    float64
#  8   접종률_순위     135 non-null    float64
#  9   1차접종       135 non-null    float64
#  10  2차접종       135 non-null    float64
#  11  위중증        104 non-null    object
#  12  치명(%)      135 non-null    object
#  13  완치(%)      132 non-null    float64
#  14  확진자1일      109 non-null    float64
#  15  사망자합계      135 non-null    int64
#  16  사망자1일      91 non-null     float64
#  17  완치합계       132 non-null    float64
#  18  완치1일       96 non-null     float64
# ...

# %%
sns.lmplot(x='2차접종', y='인구당확진자비율', data=corona_pop_5M)

# %%
corona_pop_5M[['인구당확진자비율', '2차접종']].corr()
# Out:
#           인구당확진자비율      2차접종
# 인구당확진자비율  1.000000  0.648986
# 2차접종      0.648986  1.000000

# %%
sns.lmplot(x='2차접종', y='사망률', data=corona_pop_5M)

# %%
corona_pop_5M[['인구당확진자비율', '사망률']].corr()
# Out:
#           인구당확진자비율       사망률
# 인구당확진자비율  1.000000  0.726676
# 사망률       0.726676  1.000000

# %%
sns.lmplot(x='2차접종', y='위중증률', data=corona_pop_5M)

# %%
corona_pop_5M[['2차접종', '위중증률']].corr()
# Out:
#          2차접종     위중증률
# 2차접종  1.00000 -0.20749
# 위중증률 -0.20749  1.00000

# %%
sns.histplot(x="인구수", data=corona_pop_5M)
# Out:
# <AxesSubplot:xlabel='인구수', ylabel='Count'>

# %%
corona_pop_5M["인구수"].describe()
# Out:
# count    1.140000e+02
# mean     6.550976e+07
# std      1.889375e+08
# min      5.057681e+06
# 25%      9.893953e+06
# 50%      1.974426e+07
# 75%      4.560470e+07
# max      1.439324e+09
# Name: 인구수, dtype: float64

# %%
corona_pop_5M.columns
# Out:
# Index(['국가명', 'eng_code', '발생률', '인구수', '확진자_합계', '백신접종', '백신보유량(인구)',
#        '발생률_순위', '접종률_순위', '1차접종', '2차접종', '위중증', '치명(%)', '완치(%)', '확진자1일',
#        '사망자합계', '사망자1일', '완치합계', '완치1일', '접종비율(일간)', '인구당확진자비율', '사망률',
#        '위중증_수', '위중증_증감', '위중증_수2', '위중증률'],
#       dtype='object')

# %%
corona_pop_5M[['2차접종', '인구당확진자비율']].corr()
# Out:
#               2차접종  인구당확진자비율
# 2차접종      1.000000  0.648986
# 인구당확진자비율  0.648986  1.000000

# %%
sns.lmplot(x="2차접종", y="인구당확진자비율", data=corona_pop_5M)

# %%
corona_pop_5M.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 114 entries, 0 to 163
# Data columns (total 26 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   국가명        114 non-null    object
#  1   eng_code   114 non-null    object
#  2   발생률        114 non-null    int64
#  3   인구수        114 non-null    int64
#  4   확진자_합계     114 non-null    int64
#  5   백신접종       114 non-null    float64
#  6   백신보유량(인구)  114 non-null    float64
#  7   발생률_순위     114 non-null    float64
#  8   접종률_순위     114 non-null    float64
#  9   1차접종       114 non-null    float64
#  10  2차접종       114 non-null    float64
#  11  위중증        86 non-null     object
#  12  치명(%)      114 non-null    object
#  13  완치(%)      111 non-null    float64
#  14  확진자1일      90 non-null     float64
#  15  사망자합계      114 non-null    int64
#  16  사망자1일      76 non-null     float64
#  17  완치합계       111 non-null    float64
#  18  완치1일       78 non-null     float64
# ...

# %%
corona_pop_5M["위중증_수2"].unique()
# Out:
# array([24327,  8944,  8318,  1020,  2300,  1832,   633,  6707,  1496,
#          542,  1028,   530, 31073,  1217,  4798,   113,  3170,   177,
#         1043,  1191,   208,   618,    28,  1458,   434,   638,  1403,
#         4387,   714,  4840,   218,   952,    43,    86,   776,   181,
#          221,   260,    45,   509,   503,   219,   380,   348,   200,
#          339,     5,   759,   489,   220,   391,    37,    60,   515,
#          681,    22,   784,    19,    90,   332,   109,    11,    21,
#           20,   131,    23,  1124,    32,    12,    42,   381,   127,
#          292,   152,     7,    67,     8,     3,    24,     2],
#       dtype=int16)

# %%
corona_pop_5M = corona_pop_5M.loc[ corona_pop_5M["위중증"].notnull() , : ]
corona_pop_5M.shape
# Out:
# (86, 26)

# %%
corona_pop_5M.head()
# Out:
#    국가명 eng_code     발생률         인구수    확진자_합계         백신접종  백신보유량(인구)  발생률_순위  \
# 0   미국     U.S.  129632   331002651  42908619  385586020.0       60.2    13.0
# 1   인도    India   24277  1380004385  33483170  808389300.0       29.6   101.0
# 2  브라질   Brazil   99924   212559417  21239783  222322660.0       53.9    27.0
# 3   영국     U.K.  109444    67886011   7429746   93002090.0       69.6    21.0
# 4  러시아   Russia   49986   145934462   7294672   87810616.0       29.9    77.0
#
#    접종률_순위  1차접종  2차접종          위중증 치명(%)  완치(%)    확진자1일   사망자합계  사망자1일  \
# 0    46.0  63.8  54.6  24327\n-523   1.6   75.8  41814.0  691992  430.0
# 1    99.0  43.7  14.5         8944   1.3   97.7  32085.0  445248  349.0
# 2    62.0  69.4  37.8         8318   2.8   95.5   9458.0  590786  239.0
# 3    25.0  72.7  66.5         1020   1.8   80.5  29007.0  135203   56.0
# 4    97.0  31.9  27.6         2300   2.7   89.3  19744.0  198996  778.0
#
# ...

# %%
corona_5M_part = corona_pop_5M[["국가명", "인구수","2차접종", "위중증"]]
corona_5M_part.head()
# Out:
#    국가명         인구수  2차접종          위중증
# 0   미국   331002651  54.6  24327\n-523
# 1   인도  1380004385  14.5         8944
# 2  브라질   212559417  37.8         8318
# 3   영국    67886011  66.5         1020
# 4  러시아   145934462  27.6         2300

# %%
corona_5M_part[["위중증_수", "위중증_증감"]] = corona_5M_part["위중증"].str.split("\n", expand=True)
# Out:
# C:\Users\jypark\anaconda3\lib\site-packages\pandas\core\frame.py:3191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
corona_5M_part.head()
# Out:
#    국가명         인구수  2차접종          위중증  위중증_수 위중증_증감
# 0   미국   331002651  54.6  24327\n-523  24327   -523
# 1   인도  1380004385  14.5         8944   8944   None
# 2  브라질   212559417  37.8         8318   8318   None
# 3   영국    67886011  66.5         1020   1020   None
# 4  러시아   145934462  27.6         2300   2300   None

# %%
corona_5M_part["위중증_수"] = corona_5M_part["위중증_수"].astype("int16")
corona_5M_part.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 86 entries, 0 to 159
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   국가명     86 non-null     object
#  1   인구수     86 non-null     int64
#  2   2차접종    86 non-null     float64
#  3   위중증     86 non-null     object
#  4   위중증_수   86 non-null     int16
#  5   위중증_증감  39 non-null     object
# dtypes: float64(1), int16(1), int64(1), object(3)
# memory usage: 4.2+ KB
# <ipython-input-93-edec251cfe6b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   corona_5M_part["위중증_수"] = corona_5M_part["위중증_수"].astype("int16")

# %%
corona_5M_part["위중증률"] = corona_5M_part["위중증_수"] / corona_5M_part["인구수"]
# Out:
# <ipython-input-95-6cf1d564cc28>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   corona_5M_part["위중증률"] = corona_5M_part["위중증_수"] / corona_5M_part["인구수"]

# %%
corona_5M_part.head()
# Out:
#    국가명         인구수  2차접종          위중증  위중증_수 위중증_증감      위중증률
# 0   미국   331002651  54.6  24327\n-523  24327   -523  0.000073
# 1   인도  1380004385  14.5         8944   8944   None  0.000006
# 2  브라질   212559417  37.8         8318   8318   None  0.000039
# 3   영국    67886011  66.5         1020   1020   None  0.000015
# 4  러시아   145934462  27.6         2300   2300   None  0.000016

# %%
corona_pop_5M[['인구수', '위중증률']].corr()
# Out:
#            인구수      위중증률
# 인구수   1.000000  0.002863
# 위중증률  0.002863  1.000000

# %%
corona_pop_5M[['인구수', '사망률']].corr()
# Out:
#           인구수       사망률
# 인구수  1.000000 -0.052984
# 사망률 -0.052984  1.000000

# %%
sns.lmplot(x="인구수", y="사망률", data=corona_pop_5M)

# %%
corona_pop_5M_10M = corona_pop_5M.loc[corona["인구수"] < 10000000 , :]
sns.lmplot(x="인구수", y="사망률", data=corona_pop_5M_10M)

# %% [markdown]
# #### 타이타닉

# %%
train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")

train.shape, test.shape
# Out:
# ((891, 12), (418, 11))

# %%
train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
train.describe(include = ["O"])
# Out:
#                                                    Name   Sex Ticket Cabin  \
# count                                               891   891    891   204
# unique                                              891     2    681   147
# top     Drew, Mrs. James Vivian (Lulu Thorne Christian)  male   1601    G6
# freq                                                  1   577      7     4
#
#        Embarked
# count       889
# unique        3
# top           S
# freq        644

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
train[["Pclass", "Survived"]].groupby(["Pclass"]).count()
# Out:
#         Survived
# Pclass
# 1            216
# 2            184
# 3            491

# %%
train.groupby(["Pclass"]).count()
# Out:
#         PassengerId  Survived  Name  Sex  Age  SibSp  Parch  Ticket  Fare  \
# Pclass
# 1               216       216   216  216  186    216    216     216   216
# 2               184       184   184  184  173    184    184     184   184
# 3               491       491   491  491  355    491    491     491   491
#
#         Cabin  Embarked
# Pclass
# 1         176       214
# 2          16       184
# 3          12       491

# %%
train.SibSp.unique()
# Out:
# array([1, 0, 3, 4, 2, 5, 8], dtype=int64)

# %%
train[["SibSp", "Survived"]].groupby(["SibSp"]).count()
# Out:
#        Survived
# SibSp
# 0           608
# 1           209
# 2            28
# 3            16
# 4            18
# 5             5
# 8             7

# %%
train[["SibSp", "Age"]].groupby(["SibSp"]).mean()
# Out:
#              Age
# SibSp
# 0      31.397558
# 1      30.089727
# 2      22.620000
# 3      13.916667
# 4       7.055556
# 5      10.200000
# 8            NaN

# %%
train.groupby(['SibSp']).mean()
# Out:
#        PassengerId  Survived    Pclass        Age     Parch       Fare
# SibSp
# 0       455.370066  0.345395  2.351974  31.397558  0.185855  25.692028
# 1       439.727273  0.535885  2.057416  30.089727  0.655502  44.147370
# 2       412.428571  0.464286  2.357143  22.620000  0.642857  51.753718
# 3       321.562500  0.250000  2.562500  13.916667  1.312500  68.908862
# 4       381.611111  0.166667  3.000000   7.055556  1.500000  31.855556
# 5       336.800000  0.000000  3.000000  10.200000  2.000000  46.900000
# 8       481.714286  0.000000  3.000000        NaN  2.000000  69.550000

# %%
train.groupby(['SibSp']).mean()["Age"]
# Out:
# SibSp
# 0    31.397558
# 1    30.089727
# 2    22.620000
# 3    13.916667
# 4     7.055556
# 5    10.200000
# 8          NaN
# Name: Age, dtype: float64

# %% [markdown]
# ### Pclass별 나이 연령대

# %%
dat = train.groupby(["Pclass"])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-129-cae142befba8> in <module>
#       1 dat = train.groupby(["Pclass"])
# ----> 2 dat.info()
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     750             return self[attr]
#     751
# --> 752         raise AttributeError(
#     753             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     754         )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'info'

# %%
dat.median()
# Out:
#         PassengerId  Survived   Age  SibSp  Parch     Fare
# Pclass
# 1             472.0       1.0  37.0    0.0    0.0  60.2875
# 2             435.5       0.0  29.0    0.0    0.0  14.2500
# 3             432.0       0.0  24.0    0.0    0.0   8.0500

# %%
dat = train.groupby(["Pclass", "Sex", "Embarked"], as_index=False).count()
dat
# Out:
#     Pclass     Sex Embarked  PassengerId  Survived  Name  Age  SibSp  Parch  \
# 0        1  female        C           43        43    43   38     43     43
# 1        1  female        Q            1         1     1    1      1      1
# 2        1  female        S           48        48    48   44     48     48
# 3        1    male        C           42        42    42   36     42     42
# 4        1    male        Q            1         1     1    1      1      1
# 5        1    male        S           79        79    79   64     79     79
# 6        2  female        C            7         7     7    7      7      7
# 7        2  female        Q            2         2     2    1      2      2
# 8        2  female        S           67        67    67   66     67     67
# 9        2    male        C           10        10    10    8     10     10
# 10       2    male        Q            1         1     1    1      1      1
# ...

# %%
dat.sort_values(by="Survived", ascending=False)
# Out:
#     Pclass     Sex Embarked  PassengerId  Survived  Name  Age  SibSp  Parch  \
# 17       3    male        S          265       265   265  214    265    265
# 11       2    male        S           97        97    97   90     97     97
# 14       3  female        S           88        88    88   76     88     88
# 5        1    male        S           79        79    79   64     79     79
# 8        2  female        S           67        67    67   66     67     67
# 2        1  female        S           48        48    48   44     48     48
# 15       3    male        C           43        43    43   25     43     43
# 0        1  female        C           43        43    43   38     43     43
# 3        1    male        C           42        42    42   36     42     42
# 16       3    male        Q           39        39    39   14     39     39
# 13       3  female        Q           33        33    33   10     33     33
# ...

# %%
train.groupby(["Pclass", "Sex", "Embarked", "Parch"]).count()
# Out:
#                               PassengerId  Survived  Name  Age  SibSp  Ticket  \
# Pclass Sex    Embarked Parch
# 1      female C        0               33        33    33   28     33      33
#                        1                7         7     7    7      7       7
#                        2                3         3     3    3      3       3
#               Q        0                1         1     1    1      1       1
#               S        0               28        28    28   25     28      28
#                        1               10        10    10    9     10      10
#                        2               10        10    10   10     10      10
#        male   C        0               31        31    31   25     31      31
#                        1                8         8     8    8      8       8
#                        2                3         3     3    3      3       3
#               Q        0                1         1     1    1      1       1
# ...

# %%
dat = train.groupby(["Pclass", "Sex"], as_index=False).mean()
dat
# Out:
#    Pclass     Sex  PassengerId  Survived        Age     SibSp     Parch  \
# 0       1  female   469.212766  0.968085  34.611765  0.553191  0.457447
# 1       1    male   455.729508  0.368852  41.281386  0.311475  0.278689
# 2       2  female   443.105263  0.921053  28.722973  0.486842  0.605263
# 3       2    male   447.962963  0.157407  30.740707  0.342593  0.222222
# 4       3  female   399.729167  0.500000  21.750000  0.895833  0.798611
# 5       3    male   455.515850  0.135447  26.507589  0.498559  0.224784
#
#          Fare
# 0  106.125798
# 1   67.226127
# 2   21.970121
# 3   19.741782
# 4   16.118810
# 5   12.661633

# %%
dat.sort_values(by="Survived", ascending=False)
# Out:
#    Pclass     Sex  PassengerId  Survived        Age     SibSp     Parch  \
# 0       1  female   469.212766  0.968085  34.611765  0.553191  0.457447
# 2       2  female   443.105263  0.921053  28.722973  0.486842  0.605263
# 4       3  female   399.729167  0.500000  21.750000  0.895833  0.798611
# 1       1    male   455.729508  0.368852  41.281386  0.311475  0.278689
# 3       2    male   447.962963  0.157407  30.740707  0.342593  0.222222
# 5       3    male   455.515850  0.135447  26.507589  0.498559  0.224784
#
#          Fare
# 0  106.125798
# 2   21.970121
# 4   16.118810
# 1   67.226127
# 3   19.741782
# 5   12.661633

# %%
dat = train.groupby(["Pclass", "Sex", "Embarked"], as_index=False).count()
dat
# Out:
#     Pclass     Sex Embarked  PassengerId  Survived  Name  Age  SibSp  Parch  \
# 0        1  female        C           43        43    43   38     43     43
# 1        1  female        Q            1         1     1    1      1      1
# 2        1  female        S           48        48    48   44     48     48
# 3        1    male        C           42        42    42   36     42     42
# 4        1    male        Q            1         1     1    1      1      1
# 5        1    male        S           79        79    79   64     79     79
# 6        2  female        C            7         7     7    7      7      7
# 7        2  female        Q            2         2     2    1      2      2
# 8        2  female        S           67        67    67   66     67     67
# 9        2    male        C           10        10    10    8     10     10
# 10       2    male        Q            1         1     1    1      1      1
# ...

# %%
g = sns.FacetGrid(train, col='Survived')
g.map(plt.hist, 'Age', bins=20)

# %%
# train.drop([], axis=1)  0:행, 1:열
train_df = train.drop(['Ticket', 'Cabin'], axis=1)

# %%
train_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
train_df.drop(['Name'], axis=1, inplace=True)
train_df
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare  \
# 0              1         0       3    male  22.0      1      0   7.2500
# 1              2         1       1  female  38.0      1      0  71.2833
# 2              3         1       3  female  26.0      0      0   7.9250
# 3              4         1       1  female  35.0      1      0  53.1000
# 4              5         0       3    male  35.0      0      0   8.0500
# ..           ...       ...     ...     ...   ...    ...    ...      ...
# 886          887         0       2    male  27.0      0      0  13.0000
# 887          888         1       1  female  19.0      0      0  30.0000
# 888          889         0       3  female   NaN      1      2  23.4500
# 889          890         1       1    male  26.0      0      0  30.0000
# 890          891         0       3    male  32.0      0      0   7.7500
#
#     Embarked
# 0          S
# 1          C
# 2          S
# 3          S
# 4          S
# ..       ...
# ...

# %% [markdown]
# ## 정리:

# %% [markdown]
# * [].shape, [].head(), [].tail(), [].describe(), [].columns, [].info(), [].dtypes, [].isnull().sum()
# * [].notnull().sum()
# * [].groupby([]).sum(), [].groupby([]).mean(), [].groupby([]).count()
# * pd.options.display.max_columns= 500
# #### 문자열 처리
#  * [].str.strip()
#  * [].str.split()
#  * [].str.find(), extract()..
#
# #### 자료형 변환
#  * [].astype({"col1":"int32"})
#  * dat['col1'] = dat['col1'].astype('int32')
#
# #### 데이터가 어떤 것이 있을까?
#  * [데이터셋]['컬럼명'].unique()
#
# #### 데이터가 어떤 것이 있을까? 그리고 그것의 개수확인
#  * [데이터셋]['컬럼명'].value_counts()
#
# #### 조건에 만족하는 행을 선택
#  * [].loc[행, 열]
#     * data_tmp = [].loc[ dat['col1'] > 50, :]
#     * data_tmp = [][ dat['col1'] > 50]
#
# #### 인덱스 값을 리셋
#  * tmp = [].reset_index(inplace=False)
#  * df.reset_index(inplace=True)
#
# #### 값을 정렬
#  * tmp = [].sort_values(by=['col1'], ascending=True)
#  * tmp = [].sort_index(by=['col1'], ascending=True)
